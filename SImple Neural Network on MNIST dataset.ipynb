# %% [markdown]
# # Importing required modules and dataset

# %%
from keras.datasets import mnist
from keras import models
from keras import layers
from keras.utils import to_categorical

# %% [markdown]
# # Downloading dataset

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # Creating Network and adding layers in it

# %%
network = models.Sequential()
network.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(784, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))
network.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Categorixzing data into train and test images

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %% [markdown]
# # defining labels

# %%
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %% [markdown]
# # Training model using above data

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 9s 18ms/step - loss: 0.1984 - accuracy: 0.9398
# Epoch 2/5
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0752 - accuracy: 0.9759
# Epoch 3/5
# 469/469 [==============================] - 8s 16ms/step - loss: 0.0479 - accuracy: 0.9846
# Epoch 4/5
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0336 - accuracy: 0.9890
# Epoch 5/5
# 469/469 [==============================] - 7s 16ms/step - loss: 0.0257 - accuracy: 0.9915

# %% [markdown]
# # Testing accuracy of the model

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
print('test_acc:', test_acc, 'test_loss', test_loss)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0885 - accuracy: 0.9750
# test_acc: 0.9750000238418579 test_loss 0.08849888294935226
